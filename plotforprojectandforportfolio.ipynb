# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomi-Okusanya/Tomi-Okusanya.github.io/blob/main/plotforprojectandforportfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd

# %%
evsedu=pd.read_csv('evsdatascienceset1.csv')
evsedu.head(30)
# Out:
#             Country  AvgEduTrust  AvgEmpStatus  AvgEduLevel
# 0           Austria     1.222997      0.050523     3.105634
# 1          Bulgaria     1.635659      0.122481     3.074367
# 2           Croatia     1.421277      0.119149     2.925608
# 3           Czechia     1.404568      0.084829     2.957096
# 4           Denmark     1.089816      0.047314     2.960133
# 5           Estonia     0.989316      0.036325     2.871245
# 6           Finland     0.720238      0.041667     3.097510
# 7            France     1.194748      0.091904     3.422566
# 8           Germany     1.425587      0.095300     2.748677
# 9           Hungary     1.517065      0.110922     3.077453
# 10          Iceland     1.067633      0.000000     3.104878
# 11            Italy     1.308797      0.359066     3.533088
# 12        Lithuania     1.353211      0.305046     3.138568
# 13       Montenegro     1.518072      0.496386     3.048662
# 14      Netherlands     1.168768      0.049467     3.047904
# ...

# %%
gdp18=pd.read_csv('gdp18dataregressdatascience.csv')
gdp18.head(30)
# Out:
#             Country  GDPCAP18
# 0           Austria     37720
# 1          Bulgaria      6330
# 2           Croatia     12200
# 3           Czechia     17990
# 4           Denmark     48450
# 5           Estonia     14970
# 6           Finland     36740
# 7            France     32820
# 8          Germany      35690
# 9           Hungary     12690
# 10          Iceland     39090
# 11            Italy     27030
# 12        Lithuania     13400
# 13       Montenegro      6230
# 14      Netherlands     41450
# 15  North Macedonia      4130
# 16           Norway     69440
# 17           Poland     12420
# 18         Portugal     18190
# 19          Romania      8700
# 20           Serbia      5200
# 21         Slovakia     15510
# 22         Slovenia     20240
# 23            Spain     24880
# 24           Sweden     43760
# 25      Switzerland     62500
# 26   United Kingdom     32640

# %%
x=evsedu['AvgEduLevel']
y=gdp18['GDPCAP18']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

plt.scatter(x,y)

# %%
plt.scatter(x, y)


plt.xlabel('Average Education Level By Country')
plt.ylabel('GDP per Capita in 2018')
# Out:
# Text(0, 0.5, 'GDP per Capita in 2018')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0,10,1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# This is Linear Regression but clearly inappropriate for describing the relationship between education level in a nation and income level of that country.

# %%
from sklearn.preprocessing import PolynomialFeatures

x=evsedu['AvgEduLevel']
poly.fit_transform(x[:, None])
y=gdp18['GDPCAP18']

from sklearn.pipeline import make_pipeline
poly_model = make_pipeline(PolynomialFeatures(),
                           LinearRegression())

poly_model.fit(x[:, np.newaxis], y)
xfit= np.linspace(0,10,1000)
yfit = poly_model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit)
plt.xlabel('Average Education Level By Country')
plt.ylabel('GDP per Capita in 2018')
plt.xlim([2.5,5])
plt.ylim([1000,75000])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   # This is added back by InteractiveShellApp.init_path()
# (1000.0, 75000.0)
